# %% [markdown]
# ```
# Лабораторная работа № 2
# Дисциплина «Операционные системы»
# ```
# Студент:Олейник Артём Александрович
#
# ```
# Группа:НКАбд- 03 - 22
# ```
#
# # Цели лабораторной работы
#
# ●Изучить идеологию и применение средств
#
# ●контроля версий.
#
# ●Освоить умения по работе с git()
#
#
# # Основные задачи
#
# ●Зарегистрироваться на Github
#
# ●Создать базовую конфигурацию для работы с git
#
# ●Создать ключ SSH
#
# ●Создать ключ PGP
#
# ●Настроить подписки git
#
# ●Создать локальный каталог для выполнения заданий
#
# ●по предмету
#
#
# # Вывод
#
# ●Изучил средства контроля версий и научился
# применять их.Освоил работу с git,научился
# подключать репозитории,добавлять и удалять
# файлы.
