# %% [markdown]
# ```
# Лабораторная работа № 1
# Дисциплина «Операционные системы»
# ```
# Студент:Олейник Артём Александрович
#
# ```
# Группа:НКАбд- 03 - 22
# ```
#
# ```
# Цели лабораторной работы
# ```
# ● 1 .Приобретение практических навыков
# установки опреационной системы на
# виртуальную машину
#
# ● 2 .Приобретение навыков настройки
# минимально необходимых для дальнейшей
# работы сервисов
#
# ● 3 .Выполнение Д/З
#
#
# ```
# Основный задачи
# ```
# 1.Запуск VB и создание новой виртуальной
# машины(операционная система Linux(Fedora))
#
# 2.Настройка установки операционной системы
#
# 3.Установка имени и пароля
# пользователя(Таких же как в компьютерных
# классах)
#
# 4.Подключение образа диска дополнений
# гостевой ОС
#
# 5.Выполнение Д/З
#
#
# ```
# Вывод
# ```
# ●В ходе выполнения данной лабораторной
# работы я научился устанавливать на
# виртуальную машину (Virtual Box)
# Операционную систему Linux(Fedora),а также
# научился настраивать её для комфортного
# пользования.Также я научился устанавливать
# «пакет» необходимых мне программ.
